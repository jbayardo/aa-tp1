# %%
import json
import pandas as pd
import numpy as np
import email as em

# Leo los mails (poner los paths correctos).
ham_txt = json.load(open('./data/ham_dev.json'))
spam_txt = json.load(open('./data/spam_dev.json'))

txt = ham_txt + spam_txt
output = []

for (nro, text) in enumerate(txt):
    current = {}

    if nro <= len(ham_txt):
        # HAM es -1
        current['class'] = -1
    else:
        # SPAM es 1
        current['class'] = 1

    current['email'] = text
    output.append(current)

# This is the merged, created dataset
df = pd.DataFrame(output)

# Split and save holdout and training data
# We hold out about 10% of the data
mask = np.random.rand(len(df)) < 0.8

development = df[mask]
development.to_msgpack('./data/development.msg')

holdout = df[~mask]
holdout.to_msgpack('./data/holdout.msg')

# %%
development
# Out:
#        class                                              email
# 0         -1  message-id: <13247446.1075856567056.javamail.e...
# 1         -1  message-id: <2011334.1075840007235.javamail.ev...
# 2         -1  message-id: <18606548.1075840884320.javamail.e...
# 3         -1  message-id: <31974158.1075845117294.javamail.e...
# 4         -1  message-id: <5265286.1075840899541.javamail.ev...
# 6         -1  message-id: <3906275.1075857067358.javamail.ev...
# 7         -1  message-id: <8305802.1075863310355.javamail.ev...
# 8         -1  message-id: <2430584.1075857027581.javamail.ev...
# 9         -1  message-id: <28740831.1075840828087.javamail.e...
# 11        -1  message-id: <15795469.1075840776586.javamail.e...
# 13        -1  message-id: <19128202.1075845113091.javamail.e...
# 14        -1  message-id: <8517714.1075860996279.javamail.ev...
# 15        -1  message-id: <31807933.1075857050030.javamail.e...
# 16        -1  message-id: <9922866.1075840856119.javamail.ev...
# 17        -1  message-id: <13707292.1075857078628.javamail.e...
# 19        -1  message-id: <29923791.1075854356421.javamail.e...
# 20        -1  message-id: <29333976.1075840822787.javamail.e...
# 21        -1  message-id: <10639722.1075840894160.javamail.e...
# 22        -1  message-id: <23895888.1075860977861.javamail.e...
# 23        -1  message-id: <9171773.1075855929061.javamail.ev...
# 24        -1  message-id: <23635073.1075854304488.javamail.e...
# 25        -1  message-id: <26969913.1075863303657.javamail.e...
# 26        -1  message-id: <29409784.1075854324239.javamail.e...
# 27        -1  message-id: <20581453.1075854144582.javamail.e...
# 29        -1  message-id: <24667587.1075854130574.javamail.e...
# 30        -1  message-id: <5836394.1075855013676.javamail.ev...
# 31        -1  message-id: <8436997.1075855882343.javamail.ev...
# 32        -1  message-id: <2952607.1075856588443.javamail.ev...
# 33        -1  message-id: <1031644.1075856569384.javamail.ev...
# 34        -1  message-id: <30512073.1075840820438.javamail.e...
# ...      ...                                                ...
# 89959      1  Recieved: from nahou-mscnx06p.corp.enron.com (...
# 89960      1  Recieved: from nahou-mscnx06p.corp.enron.com (...
# 89962      1  Received: from nahou-mscnx06p.corp.enron.com (...
# 89963      1  Received: from nahou-mscnx06p.corp.enron.com (...
# 89964      1  Received: from nahou-mscnx06p.corp.enron.com (...
# 89966      1  Received: from nahou-mscnx06p.corp.enron.com (...
# 89967      1  Received: from nahou-mscnx06p.corp.enron.com (...
# 89968      1  Received: from nahou-mscnx06p.corp.enron.com (...
# 89970      1  Recieved: from nahou-mscnx06p.corp.enron.com (...
# 89972      1  Received: from nahou-mscnx06p.corp.enron.com (...
# 89974      1  Received: from nahou-mscnx06p.corp.enron.com (...
# 89975      1  Received: from nahou-mscnx06p.corp.enron.com (...
# 89976      1  Recieved: from nahou-mscnx06p.corp.enron.com (...
# 89977      1  Received: from nahou-mscnx06p.corp.enron.com (...
# 89978      1  Received: from nahou-mscnx06p.corp.enron.com (...
# 89979      1  Received: from nahou-mscnx06p.corp.enron.com (...
# 89980      1  Received: from nahou-mscnx06p.corp.enron.com (...
# 89982      1  Received: from nahou-mscnx06p.corp.enron.com (...
# 89984      1  Received: from nahou-mscnx06p.corp.enron.com (...
# 89985      1  Recieved: from nahou-mscnx06p.corp.enron.com (...
# 89986      1  Received: from nahou-mscnx06p.corp.enron.com (...
# 89988      1  Received: from nahou-mscnx06p.corp.enron.com (...
# 89989      1  Received: from nahou-mscnx06p.corp.enron.com (...
# 89990      1  Received: from nahou-mscnx06p.corp.enron.com (...
# 89991      1  Received: from nahou-mscnx06p.corp.enron.com (...
# 89992      1  Received: from nahou-mscnx06p.corp.enron.com (...
# 89995      1  Received: from nahou-mscnx06p.corp.enron.com (...
# 89996      1  Received: from nahou-mscnx06p.corp.enron.com (...
# 89997      1  Recieved: from nahou-mscnx06p.corp.enron.com (...
# 89998      1  Received: from nahou-mscnx06p.corp.enron.com (...
#
# [72027 rows x 2 columns]

# %%
# Load up development dataset
import pandas as pd
import email

print("Loading data")
df = pd.read_msgpack('./data/development.msg', encoding='latin-1')
df['email'] = df['email'].apply(email.message_from_string)
# Out:
# Loading data

# %%
import pandas as pd
import re
import multiprocessing
import collections

def generate_content_types(row):
    email = row['email']
    output = collections.defaultdict(False)
    check = ['x-world', 'application', 'text', 'text/plain', 'text/html', 'video', 'audio', 'image', 'drawing', 'model', 'multipart', 'x-conference', 'i-world', 'music', 'message', 'x-music', 'www', 'chemical', 'paleovu', 'windows', 'xgl']
    
    for part in email.walk():
        ct = part.get_content_type()
        
        for kind in check:
            output['has_' + kind] |= ct.startswith(kind)
    
    return output

def generate_number_of_spaces(row):
    email = str(row['email'])
    
    return {
        'spaces': email.count(' '),
        'newlines': email.count('\n')
    }

def number_of_images(row):
    email = row['email']
    output = { 'multipart_number': 0, 'number_of_images': 0 }
    rgx = re.compile('\.(jpeg|jpg|png|gif|bmp)')
    
    for part in email.walk():
        output['multipart_number'] += 1
        
        if part.get_content_type().startswith('image/'):
            output['number_of_images'] += 1
        elif part.get_content_type() == 'text/html' or part.get_content_type() == 'text/plain':
            output['number_of_images'] += len(re.findall(rgx, part.get_payload()))
    
    return output

def 

# Functions which create the output features
transforms = [
    lambda row: {'class': row['class']},
    lambda row: {'length': len(row['email'])},
    generate_multipart_number,
    generate_content_types,
    generate_number_of_spaces,
    number_of_images]

# Set up thread pool
def transform_row(x):
    (index, row) = x
    current = {}
    
    for function in transforms:
        current.update(function(row))
    
    return current

print("Processing")
pool = multiprocessing.Pool(20)

# Create dataframe
transformed = pool.map(transform_row, df.iterrows())

print("Done!")

try:
    del ds
except:
    pass

ds = pd.DataFrame(transformed)
# Out:
# Processing

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.cross_validation import cross_val_score
from sklearn.metrics import confusion_matrix

dataset = ds[[x for x in ds.columns if x != 'class']].values
labels = ds['class'].apply(lambda x: x == 'spam')

model = DecisionTreeClassifier()
res = cross_val_score(model, dataset, labels, cv=10, scoring='roc_auc')
print(np.mean(res), np.std(res))

# %%
import collections

c = collections.Counter()

for row in df[df['class'] == 'spam']['email']:
    for entry in row.walk():
        c[entry.get_content_type()] += 1
        
c.most_common(50)

# %%
# Calculate number people in xbcc xto, ...
import numpy as np

def get_receiver_numbers(row):
    def normalize(contacts):
        if pd.isnull(contacts):
            return []
        else:
            contacts = str(contacts)
            contacts = ''.join([x for x in contacts if x not in ['#', '\n', '\t', '\r']])
            contacts = contacts.split(',')
            return [c for c in contacts if c != '']
    
    check = ['to', 'x-to', 'from', 'x-from', 'cc', 'x-cc', 'bcc', 'x-bcc']
    output = {}
    
    for header in check:
        output[header] = 0
    
    for header in row['email'].keys():
        header = header.lower()
        
        if header in check:
            output[header] = len(normalize(row['email'][header]))
    
    return output

# %%
df['email'][0].keys()
# Out:
# ['message-id',
#  'date',
#  'from',
#  'to',
#  'subject',
#  'cc',
#  'mime-version',
#  'content-type',
#  'content-transfer-encoding',
#  'bcc',
#  'x-from',
#  'x-to',
#  'x-cc',
#  'x-bcc',
#  'x-origin',
#  'x-filename']

# %%
df['email'].apply(lambda x: x.get_subject())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-e6b5430afbc5> in <module>()
# ----> 1 df['email'].apply(lambda x: x.get_subject())
#
# C:\Anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    2218         else:
#    2219             values = self.asobject
# -> 2220             mapped = lib.map_infer(values, f, convert=convert_dtype)
#    2221
#    2222         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\src\inference.pyx in pandas.lib.map_infer (pandas\lib.c:62658)()
#
# <ipython-input-7-e6b5430afbc5> in <lambda>(x)
# ----> 1 df['email'].apply(lambda x: x.get_subject())
#
# AttributeError: 'Message' object has no attribute 'get_subject'

# %%
import pandas

df = pandas.read_msgpack('./data/processed.msg')

# %%
df
# Out:
#        class has_application has_audio has_chemical has_drawing has_i-world  \
# 0         -1           False     False        False       False       False
# 1         -1           False     False        False       False       False
# 2         -1           False     False        False       False       False
# 3         -1           False     False        False       False       False
# 4         -1           False     False        False       False       False
# 5         -1           False     False        False       False       False
# 6         -1           False     False        False       False       False
# 7         -1           False     False        False       False       False
# 8         -1           False     False        False       False       False
# 9         -1           False     False        False       False       False
# 10        -1           False     False        False       False       False
# 11        -1           False     False        False       False       False
# 12        -1           False     False        False       False       False
# 13        -1           False     False        False       False       False
# 14        -1           False     False        False       False       False
# 15        -1           False     False        False       False       False
# 16        -1           False     False        False       False       False
# 17        -1           False     False        False       False       False
# 18        -1           False     False        False       False       False
# 19        -1           False     False        False       False       False
# 20        -1           False     False        False       False       False
# 21        -1           False     False        False       False       False
# 22        -1           False     False        False       False       False
# 23        -1           False     False        False       False       False
# 24        -1           False     False        False       False       False
# 25        -1           False     False        False       False       False
# 26        -1           False     False        False       False       False
# 27        -1           False     False        False       False       False
# 28        -1           False     False        False       False       False
# 29        -1           False     False        False       False       False
# ...      ...             ...       ...          ...         ...         ...
# 71997      1           False     False        False       False       False
# 71998      1           False     False        False       False       False
# 71999      1           False     False        False       False       False
# 72000      1           False     False        False       False       False
# 72001      1           False     False        False       False       False
# 72002      1           False     False        False       False       False
# 72003      1           False     False        False       False       False
# 72004      1           False     False        False       False       False
# 72005      1           False     False        False       False       False
# 72006      1           False     False        False       False       False
# 72007      1           False     False        False       False       False
# 72008      1           False     False        False       False       False
# 72009      1           False     False        False       False       False
# 72010      1           False     False        False       False       False
# 72011      1           False     False        False       False       False
# 72012      1           False     False        False       False       False
# 72013      1           False     False        False       False       False
# 72014      1           False     False        False       False       False
# 72015      1           False     False        False       False       False
# 72016      1           False     False        False       False       False
# 72017      1           False     False        False       False       False
# 72018      1           False     False        False       False       False
# 72019      1           False     False        False       False       False
# 72020      1           False     False        False       False       False
# 72021      1           False     False        False       False       False
# 72022      1           False     False        False       False       False
# 72023      1           False     False        False       False       False
# 72024      1           False     False        False       False       False
# 72025      1           False     False        False       False       False
# 72026      1           False     False        False       False       False
#
#       has_image has_message has_model has_multipart  \
# 0         False       False     False         False
# 1         False       False     False         False
# 2         False       False     False         False
# 3         False       False     False         False
# 4         False       False     False         False
# 5         False       False     False         False
# 6         False       False     False         False
# 7         False       False     False         False
# 8         False       False     False         False
# 9         False       False     False         False
# 10        False       False     False         False
# 11        False       False     False         False
# 12        False       False     False         False
# 13        False       False     False         False
# 14        False       False     False         False
# 15        False       False     False         False
# 16        False       False     False         False
# 17        False       False     False         False
# 18        False       False     False         False
# 19        False       False     False         False
# 20        False       False     False         False
# 21        False       False     False         False
# 22        False       False     False         False
# 23        False       False     False         False
# 24        False       False     False         False
# 25        False       False     False         False
# 26        False       False     False         False
# 27        False       False     False         False
# 28        False       False     False         False
# 29        False       False     False         False
# ...         ...         ...       ...           ...
# 71997     False       False     False         False
# 71998     False       False     False          True
# 71999     False       False     False         False
# 72000     False       False     False          True
# 72001     False       False     False          True
# 72002     False       False     False         False
# 72003     False       False     False         False
# 72004     False       False     False         False
# 72005     False       False     False         False
# 72006     False       False     False          True
# 72007     False       False     False         False
# 72008     False       False     False          True
# 72009     False       False     False         False
# 72010      True       False     False          True
# 72011     False       False     False         False
# 72012     False       False     False         False
# 72013     False       False     False         False
# 72014     False       False     False         False
# 72015     False       False     False          True
# 72016     False       False     False         False
# 72017     False       False     False         False
# 72018     False       False     False          True
# 72019     False       False     False         False
# 72020     False       False     False          True
# 72021     False       False     False          True
# 72022     False       False     False          True
# 72023     False       False     False         False
# 72024     False       False     False         False
# 72025     False       False     False         False
# 72026     False       False     False          True
#
#                       ...                 people_in_cc people_in_from  \
# 0                     ...                            2              1
# 1                     ...                           -1              1
# 2                     ...                            4              1
# 3                     ...                           -1              1
# 4                     ...                           -1              1
# 5                     ...                            4              1
# 6                     ...                           -1              1
# 7                     ...                            3              1
# 8                     ...                            1              1
# 9                     ...                           -1              1
# 10                    ...                           -1              1
# 11                    ...                           -1              1
# 12                    ...                            2              1
# 13                    ...                           -1              1
# 14                    ...                           -1              1
# 15                    ...                           -1              1
# 16                    ...                           -1              1
# 17                    ...                           -1              1
# 18                    ...                            2              1
# 19                    ...                            1              1
# 20                    ...                           -1              1
# 21                    ...                           -1              1
# 22                    ...                           -1              1
# 23                    ...                            2              1
# 24                    ...                           -1              1
# 25                    ...                            1              1
# 26                    ...                           -1              1
# 27                    ...                            1              1
# 28                    ...                            1              1
# 29                    ...                            2              1
# ...                   ...                          ...            ...
# 71997                 ...                           -1              1
# 71998                 ...                           -1              1
# 71999                 ...                           -1              1
# 72000                 ...                           -1              1
# 72001                 ...                           -1              1
# 72002                 ...                           -1              1
# 72003                 ...                           -1              1
# 72004                 ...                           -1              1
# 72005                 ...                           -1              1
# 72006                 ...                           -1              1
# 72007                 ...                           -1              1
# 72008                 ...                           -1              1
# 72009                 ...                           -1              1
# 72010                 ...                           -1              1
# 72011                 ...                           -1              1
# 72012                 ...                           -1              1
# 72013                 ...                           -1              1
# 72014                 ...                           -1              1
# 72015                 ...                           -1              1
# 72016                 ...                           -1              1
# 72017                 ...                           -1              1
# 72018                 ...                           -1              1
# 72019                 ...                           -1              1
# 72020                 ...                           -1              1
# 72021                 ...                           -1              1
# 72022                 ...                           -1              1
# 72023                 ...                           -1              1
# 72024                 ...                           -1              1
# 72025                 ...                           -1              1
# 72026                 ...                           -1              1
#
#       people_in_to people_in_x-bcc people_in_x-cc people_in_x-from  \
# 0                1               0              2                1
# 1                1               0              0                2
# 2                8               0              8                2
# 3                1               0              0                2
# 4                3               0              0                1
# 5                1               0              4                1
# 6                1               0              0                2
# 7                2               0              3                1
# 8                3               0              2                2
# 9                1               0              0                1
# 10               1               0              0                2
# 11              -1               0              0                1
# 12               1               0              2                1
# 13               1               0              0                1
# 14               2               0              0                1
# 15              44               0              0                1
# 16               1               0              0                2
# 17               1               0              0                2
# 18               7               0              4                2
# 19               1               0              1                1
# 20               3               0              0                1
# 21               1               0              0                2
# 22              24               0              0                1
# 23               5               0              2                1
# 24              13               0              0                1
# 25               6               0              2                2
# 26               1               0              0                1
# 27               1               0              1                1
# 28               1               0              1                1
# 29               1               0              2                1
# ...            ...             ...            ...              ...
# 71997            1              -1             -1               -1
# 71998            1              -1             -1               -1
# 71999            1              -1             -1               -1
# 72000            1              -1             -1               -1
# 72001            1              -1             -1               -1
# 72002            6              -1             -1               -1
# 72003            1              -1             -1               -1
# 72004            1              -1             -1               -1
# 72005            1              -1             -1               -1
# 72006            1              -1             -1               -1
# 72007            1              -1             -1               -1
# 72008            1              -1             -1               -1
# 72009            1              -1             -1               -1
# 72010            1              -1             -1               -1
# 72011            1              -1             -1               -1
# 72012            1              -1             -1               -1
# 72013            1              -1             -1               -1
# 72014            1              -1             -1               -1
# 72015            1              -1             -1               -1
# 72016            1              -1             -1               -1
# 72017            1              -1             -1               -1
# 72018            1              -1             -1               -1
# 72019            1              -1             -1               -1
# 72020            1              -1             -1               -1
# 72021            1              -1             -1               -1
# 72022            1              -1             -1               -1
# 72023            1              -1             -1               -1
# 72024            1              -1             -1               -1
# 72025            1              -1             -1               -1
# 72026            1              -1             -1               -1
#
#       people_in_x-to spaces title_case_words_to_words_ratio  \
# 0                  1    129                        0.000000
# 1                  1    698                        0.000000
# 2                 16    223                        0.000000
# 3                  2    167                        0.000000
# 4                  3    409                        0.000000
# 5                  1    207                        0.000000
# 6                  1     56                        0.000000
# 7                  2   1355                        0.000000
# 8                  6    231                        0.000000
# 9                  1    505                        0.000000
# 10                 2    241                        0.000000
# 11                 0     63                        0.000000
# 12                 1    214                        0.000000
# 13                 1    109                        0.000000
# 14                 2    298                        0.000000
# 15                44    158                        0.000000
# 16                 2     35                        0.000000
# 17                 2   5791                        0.000000
# 18                14    198                        0.000000
# 19                 1    242                        0.000000
# 20                 3    136                        0.000000
# 21                 2    441                        0.000000
# 22                24     77                        0.000000
# 23                 5     88                        0.000000
# 24                13    104                        0.000000
# 25                12    203                        0.000000
# 26                 1    115                        0.000000
# 27                 1    152                        0.000000
# 28                 1    433                        0.000000
# 29                 1    371                        0.000000
# ...              ...    ...                             ...
# 71997             -1    200                        0.427419
# 71998             -1    679                        0.123077
# 71999             -1   1132                        0.577722
# 72000             -1    167                        0.384615
# 72001             -1    320                        0.305263
# 72002             -1    105                        0.250000
# 72003             -1    148                        0.490153
# 72004             -1    151                        0.348578
# 72005             -1    156                        0.289474
# 72006             -1    186                        0.088889
# 72007             -1    106                        0.153846
# 72008             -1    158                        0.078125
# 72009             -1    199                        0.449153
# 72010             -1    279                        0.456522
# 72011             -1    138                        0.114286
# 72012             -1    144                        0.144444
# 72013             -1    639                        0.230894
# 72014             -1    306                        0.007201
# 72015             -1    167                        0.000000
# 72016             -1    104                        0.875000
# 72017             -1    271                        0.105882
# 72018             -1    516                        0.180556
# 72019             -1    227                        0.154930
# 72020             -1    399                        0.267123
# 72021             -1    247                        0.580645
# 72022             -1    296                        0.459677
# 72023             -1    162                        0.621053
# 72024             -1    105                        0.377383
# 72025             -1    142                        0.073171
# 72026             -1    137                        0.013699
#
#       upper_case_letters_to_letters_ratio
# 0                                0.000000
# 1                                0.000000
# 2                                0.000000
# 3                                0.000000
# 4                                0.000000
# 5                                0.000000
# 6                                0.000000
# 7                                0.000000
# 8                                0.000000
# 9                                0.000000
# 10                               0.000000
# 11                               0.000000
# 12                               0.000000
# 13                               0.000000
# 14                               0.000000
# 15                               0.000000
# 16                               0.000000
# 17                               0.000000
# 18                               0.000000
# 19                               0.000000
# 20                               0.000000
# 21                               0.000000
# 22                               0.000000
# 23                               0.000000
# 24                               0.000000
# 25                               0.000000
# 26                               0.000000
# 27                               0.000000
# 28                               0.000000
# 29                               0.000000
# ...                                   ...
# 71997                            0.427419
# 71998                            0.123077
# 71999                            0.577722
# 72000                            0.384615
# 72001                            0.305263
# 72002                            0.250000
# 72003                            0.490153
# 72004                            0.348578
# 72005                            0.289474
# 72006                            0.088889
# 72007                            0.153846
# 72008                            0.078125
# 72009                            0.449153
# 72010                            0.456522
# 72011                            0.114286
# 72012                            0.144444
# 72013                            0.230894
# 72014                            0.007201
# 72015                            0.000000
# 72016                            0.875000
# 72017                            0.105882
# 72018                            0.180556
# 72019                            0.154930
# 72020                            0.267123
# 72021                            0.580645
# 72022                            0.459677
# 72023                            0.621053
# 72024                            0.377383
# 72025                            0.073171
# 72026                            0.013699
#
# [72027 rows x 40 columns]

# %%
import sklearn.tree
from sklearn.cross_validation import cross_val_score
from sklearn.metrics import confusion_matrix
import numpy as np

dataset = df[[x for x in df.columns if x != 'class']].values
labels = df['class'].apply(lambda x: x == 1)
model = sklearn.tree.DecisionTreeClassifier()
res = cross_val_score(model, dataset, labels, cv=10, scoring='accuracy')
print(np.mean(res), np.std(res))
# Out:
# 0.973493614746 0.0201790309039

# %%
model = sklearn.tree.DecisionTreeClassifier()
model = model.fit(dataset, labels)
sklearn.tree.export_graphviz(model.tree_)

# %%
res
# Out:
# array([ 0.99888951,  0.99930594,  0.99944475,  0.99458559,  0.96126076,
#         0.9583449 ,  0.9566787 ,  0.95362399,  0.9555679 ,  0.9572341 ])

# %%
# Load up development dataset
import pandas as pd
import email

print("Loading data")
df = pd.read_msgpack('./data/development.msg', encoding='latin-1')
df['email'] = df['email'].apply(email.message_from_string)
# Out:
# Loading data

# %%
import re
for entry in df['email'].apply(lambda x: x['subject']):
    try:
        s = re.search(r'\[[A-Za-z0-9_\-]{2,}\]', entry)
        if s is not None:
            print(s)
    except:
        pass
# Out:
# <_sre.SRE_Match object; span=(4, 10), match='[edis]'>
# <_sre.SRE_Match object; span=(6, 10), match='[10]'>
# <_sre.SRE_Match object; span=(6, 13), match='[netco]'>
# <_sre.SRE_Match object; span=(0, 6), match='[EDIS]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 6), match='[EDIS]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 15), match='[MORROBAY-LIST]'>
# <_sre.SRE_Match object; span=(5, 19), match='[ordinarylife]'>
# <_sre.SRE_Match object; span=(0, 19), match='[NEWSRELEASES-LIST]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[Footballguys]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[Footballguys]'>
# <_sre.SRE_Match object; span=(5, 24), match='[FreeFootballPicks]'>
# <_sre.SRE_Match object; span=(4, 20), match='[Kidsavefriends]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[METCALF-LIST]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[Footballguys]'>
# <_sre.SRE_Match object; span=(0, 18), match='[ELECTRICITY-LIST]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(4, 15), match='[TxWAG2001]'>
# <_sre.SRE_Match object; span=(0, 17), match='[HIGHDESERT-LIST]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[AGENDAS-LIST]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[METCALF-LIST]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(6, 13), match='[Netco]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[Footballguys]'>
# <_sre.SRE_Match object; span=(63, 70), match='[FINAL]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 6), match='[EDIS]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[Footballguys]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 6), match='[EDIS]'>
# <_sre.SRE_Match object; span=(0, 6), match='[EDIS]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(5, 19), match='[ordinarylife]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(4, 20), match='[Kidsavefriends]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[Footballguys]'>
# <_sre.SRE_Match object; span=(0, 14), match='[Footballguys]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[Footballguys]'>
# <_sre.SRE_Match object; span=(0, 14), match='[Footballguys]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[Footballguys]'>
# <_sre.SRE_Match object; span=(0, 14), match='[Footballguys]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 6), match='[EDIS]'>
# <_sre.SRE_Match object; span=(0, 14), match='[Footballguys]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 6), match='[EDIS]'>
# <_sre.SRE_Match object; span=(0, 14), match='[Footballguys]'>
# <_sre.SRE_Match object; span=(0, 21), match='[TRANSPORTATION-LIST]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(4, 21), match='[venhauscampaign]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[Footballguys]'>
# <_sre.SRE_Match object; span=(0, 6), match='[EDIS]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 16), match='[ELSEGUNDO-LIST]'>
# <_sre.SRE_Match object; span=(0, 14), match='[Footballguys]'>
# <_sre.SRE_Match object; span=(0, 15), match='[MORROBAY-LIST]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(8, 15), match='[DFWH3]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(5, 19), match='[ordinarylife]'>
# <_sre.SRE_Match object; span=(0, 15), match='[MORROBAY-LIST]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 19), match='[NEWSRELEASES-LIST]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[Footballguys]'>
# <_sre.SRE_Match object; span=(0, 19), match='[NEWSRELEASES-LIST]'>
# <_sre.SRE_Match object; span=(4, 20), match='[Kidsavefriends]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[Footballguys]'>
# <_sre.SRE_Match object; span=(0, 15), match='[MORROBAY-LIST]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[Footballguys]'>
# <_sre.SRE_Match object; span=(4, 18), match='[ordinarylife]'>
# <_sre.SRE_Match object; span=(0, 14), match='[Footballguys]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 6), match='[EDIS]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(4, 20), match='[Kidsavefriends]'>
# <_sre.SRE_Match object; span=(0, 14), match='[Footballguys]'>
# <_sre.SRE_Match object; span=(0, 14), match='[Footballguys]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[Footballguys]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[Footballguys]'>
# <_sre.SRE_Match object; span=(0, 14), match='[Footballguys]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 19), match='[ASME-OMAE-Houston]'>
# <_sre.SRE_Match object; span=(4, 23), match='[NEWSRELEASES-LIST]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(4, 18), match='[ordinarylife]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[Footballguys]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[Footballguys]'>
# <_sre.SRE_Match object; span=(0, 14), match='[Footballguys]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[Footballguys]'>
# <_sre.SRE_Match object; span=(0, 14), match='[Footballguys]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 6), match='[EDIS]'>
# <_sre.SRE_Match object; span=(4, 18), match='[ordinarylife]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[Footballguys]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[Footballguys]'>
# <_sre.SRE_Match object; span=(0, 6), match='[EDIS]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[Footballguys]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 15), match='[MORROBAY-LIST]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(4, 18), match='[ordinarylife]'>
# <_sre.SRE_Match object; span=(0, 13), match='[enerfaxgold]'>
# <_sre.SRE_Match object; span=(4, 26), match='[bikehouston-announce]'>
# <_sre.SRE_Match object; span=(0, 14), match='[Footballguys]'>
# <_sre.SRE_Match object; span=(0, 14), match='[Footballguys]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(4, 15), match='[TxWAG2001]'>
# <_sre.SRE_Match object; span=(0, 14), match='[Footballguys]'>
# <_sre.SRE_Match object; span=(4, 12), match='[calrps]'>
# <_sre.SRE_Match object; span=(0, 14), match='[Footballguys]'>
# <_sre.SRE_Match object; span=(0, 14), match='[Footballguys]'>
# <_sre.SRE_Match object; span=(0, 14), match='[Footballguys]'>
# <_sre.SRE_Match object; span=(0, 14), match='[Footballguys]'>
# <_sre.SRE_Match object; span=(4, 18), match='[ordinarylife]'>
# <_sre.SRE_Match object; span=(0, 6), match='[EDIS]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[Footballguys]'>
# <_sre.SRE_Match object; span=(0, 6), match='[EDIS]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 6), match='[EDIS]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(4, 18), match='[ordinarylife]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[Footballguys]'>
# <_sre.SRE_Match object; span=(4, 15), match='[TxWAG2001]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(4, 27), match='[huskernews-press-pass]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(4, 18), match='[ordinarylife]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[Footballguys]'>
# <_sre.SRE_Match object; span=(0, 6), match='[EDIS]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[SUNRISE-LIST]'>
# <_sre.SRE_Match object; span=(4, 22), match='[ELECTRICITY-LIST]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[Footballguys]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 21), match='[TRANSPORTATION-LIST]'>
# <_sre.SRE_Match object; span=(0, 6), match='[EDIS]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 6), match='[EDIS]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 6), match='[EDIS]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[Footballguys]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 6), match='[EDIS]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(5, 19), match='[ordinarylife]'>
# <_sre.SRE_Match object; span=(0, 14), match='[Footballguys]'>
# <_sre.SRE_Match object; span=(0, 6), match='[EDIS]'>
# <_sre.SRE_Match object; span=(0, 6), match='[EDIS]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 11), match='[smu-betas]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(5, 19), match='[ordinarylife]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(4, 15), match='[TxWAG2001]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 19), match='[NEWSRELEASES-LIST]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[Footballguys]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[Footballguys]'>
# <_sre.SRE_Match object; span=(0, 6), match='[EDIS]'>
# <_sre.SRE_Match object; span=(0, 6), match='[EDIS]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[Footballguys]'>
# <_sre.SRE_Match object; span=(0, 14), match='[AGENDAS-LIST]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[Footballguys]'>
# <_sre.SRE_Match object; span=(4, 15), match='[TxWAG2001]'>
# <_sre.SRE_Match object; span=(0, 6), match='[EDIS]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[Footballguys]'>
# <_sre.SRE_Match object; span=(4, 18), match='[ordinarylife]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 6), match='[EDIS]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 6), match='[EDIS]'>
# <_sre.SRE_Match object; span=(0, 14), match='[Footballguys]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[Footballguys]'>
# <_sre.SRE_Match object; span=(0, 14), match='[Footballguys]'>
# <_sre.SRE_Match object; span=(0, 14), match='[Footballguys]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 19), match='[NEWSRELEASES-LIST]'>
# <_sre.SRE_Match object; span=(0, 14), match='[Footballguys]'>
# <_sre.SRE_Match object; span=(0, 6), match='[EDIS]'>
# <_sre.SRE_Match object; span=(0, 19), match='[NEWSRELEASES-LIST]'>
# <_sre.SRE_Match object; span=(0, 14), match='[Footballguys]'>
# <_sre.SRE_Match object; span=(0, 14), match='[Footballguys]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 19), match='[NEWSRELEASES-LIST]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 18), match='[ELECTRICITY-LIST]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[Footballguys]'>
# <_sre.SRE_Match object; span=(0, 14), match='[Footballguys]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[Footballguys]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[Footballguys]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(4, 18), match='[ordinarylife]'>
# <_sre.SRE_Match object; span=(0, 14), match='[Footballguys]'>
# <_sre.SRE_Match object; span=(0, 6), match='[EDIS]'>
# <_sre.SRE_Match object; span=(0, 19), match='[NEWSRELEASES-LIST]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[Footballguys]'>
# <_sre.SRE_Match object; span=(0, 14), match='[AGENDAS-LIST]'>
# <_sre.SRE_Match object; span=(0, 14), match='[Footballguys]'>
# <_sre.SRE_Match object; span=(4, 12), match='[calrps]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[Footballguys]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 6), match='[EDIS]'>
# <_sre.SRE_Match object; span=(0, 14), match='[enerfaxdaily]'>
# <_sre.SRE_Match object; span=(0, 14), match='[Footballguys]'>
# <_sre.SRE_Match object; span=(0, 6), match='[EDIS]'>
# <_sre.SRE_Match object; span=(39, 43), match='[ge]'>
# <_sre.SRE_Match object; span=(0, 7), match='[mpiro]'>
# <_sre.SRE_Match object; span=(13, 24), match='[mortgages]'>
# <_sre.SRE_Match object; span=(0, 13), match='[intercourse]'>
# <_sre.SRE_Match object; span=(5, 13), match='[cursor]'>
# <_sre.SRE_Match object; span=(0, 6), match='[news]'>
# <_sre.SRE_Match object; span=(4, 14), match='[toweling]'>
# <_sre.SRE_Match object; span=(4, 12), match='[betsey]'>
# <_sre.SRE_Match object; span=(0, 12), match='[auto-reply]'>
# <_sre.SRE_Match object; span=(0, 7), match='[mpiro]'>
# <_sre.SRE_Match object; span=(0, 7), match='[mpiro]'>
# <_sre.SRE_Match object; span=(3, 7), match='[16]'>
# <_sre.SRE_Match object; span=(0, 11), match='[melpomene]'>
# <_sre.SRE_Match object; span=(45, 51), match='[9185]'>
# <_sre.SRE_Match object; span=(0, 4), match='[89]'>
# <_sre.SRE_Match object; span=(4, 10), match='[sock]'>
# <_sre.SRE_Match object; span=(4, 14), match='[follower]'>
# <_sre.SRE_Match object; span=(5, 17), match='[regressive]'>
# <_sre.SRE_Match object; span=(13, 24), match='[mortgages]'>
# <_sre.SRE_Match object; span=(0, 7), match='[adult]'>
# <_sre.SRE_Match object; span=(5, 11), match='[melt]'>
# <_sre.SRE_Match object; span=(48, 60), match='[repressive]'>
# <_sre.SRE_Match object; span=(0, 7), match='[mpiro]'>
# <_sre.SRE_Match object; span=(4, 19), match='[sophisticated]'>
# <_sre.SRE_Match object; span=(2, 6), match='[18]'>
# <_sre.SRE_Match object; span=(0, 7), match='[irons]'>
# <_sre.SRE_Match object; span=(2, 6), match='[14]'>
# <_sre.SRE_Match object; span=(4, 11), match='[graff]'>
# <_sre.SRE_Match object; span=(18, 29), match='[refinance]'>
# <_sre.SRE_Match object; span=(4, 15), match='[daughters]'>
# <_sre.SRE_Match object; span=(4, 15), match='[matchless]'>
# <_sre.SRE_Match object; span=(2, 6), match='[10]'>
# <_sre.SRE_Match object; span=(2, 6), match='[16]'>
# <_sre.SRE_Match object; span=(0, 11), match='[formation]'>
# <_sre.SRE_Match object; span=(3, 7), match='[10]'>
# <_sre.SRE_Match object; span=(2, 6), match='[34]'>
# <_sre.SRE_Match object; span=(39, 49), match='[compound]'>
# <_sre.SRE_Match object; span=(0, 4), match='[44]'>
# <_sre.SRE_Match object; span=(0, 9), match='[blacken]'>
# <_sre.SRE_Match object; span=(0, 10), match='[produced]'>
# <_sre.SRE_Match object; span=(2, 6), match='[14]'>
# <_sre.SRE_Match object; span=(28, 36), match='[junior]'>
# <_sre.SRE_Match object; span=(17, 28), match='[273952435]'>
# <_sre.SRE_Match object; span=(31, 38), match='[2arm7]'>
# <_sre.SRE_Match object; span=(0, 4), match='[ia]'>
# <_sre.SRE_Match object; span=(3, 7), match='[16]'>
# <_sre.SRE_Match object; span=(5, 16), match='[grassland]'>
# <_sre.SRE_Match object; span=(28, 36), match='[healey]'>
# <_sre.SRE_Match object; span=(5, 10), match='[abe]'>
# <_sre.SRE_Match object; span=(4, 16), match='[impossible]'>
# <_sre.SRE_Match object; span=(0, 9), match='[potable]'>
# <_sre.SRE_Match object; span=(0, 10), match='[wrenches]'>
# <_sre.SRE_Match object; span=(4, 13), match='[adamson]'>
# <_sre.SRE_Match object; span=(0, 5), match='[uai]'>
# <_sre.SRE_Match object; span=(39, 50), match='[vestibule]'>
# <_sre.SRE_Match object; span=(0, 6), match='[news]'>
# <_sre.SRE_Match object; span=(0, 10), match='[flagpole]'>
# <_sre.SRE_Match object; span=(4, 14), match='[complied]'>
# <_sre.SRE_Match object; span=(2, 6), match='[10]'>
# <_sre.SRE_Match object; span=(0, 5), match='[adv]'>
# <_sre.SRE_Match object; span=(2, 6), match='[16]'>
# <_sre.SRE_Match object; span=(0, 5), match='[adv]'>
# <_sre.SRE_Match object; span=(5, 16), match='[valuables]'>
# <_sre.SRE_Match object; span=(0, 5), match='[adv]'>
# <_sre.SRE_Match object; span=(2, 6), match='[19]'>
# <_sre.SRE_Match object; span=(2, 6), match='[50]'>
# <_sre.SRE_Match object; span=(0, 13), match='[originators]'>
# <_sre.SRE_Match object; span=(28, 34), match='[lfkn]'>
# <_sre.SRE_Match object; span=(38, 46), match='[embank]'>
# <_sre.SRE_Match object; span=(4, 18), match='[recalcitrant]'>
# <_sre.SRE_Match object; span=(4, 17), match='[expenditure]'>
# <_sre.SRE_Match object; span=(0, 7), match='[mlnet]'>
# <_sre.SRE_Match object; span=(4, 18), match='[conservative]'>
# <_sre.SRE_Match object; span=(4, 14), match='[precepts]'>
# <_sre.SRE_Match object; span=(47, 52), match='[adv]'>
# <_sre.SRE_Match object; span=(0, 10), match='[patience]'>
# <_sre.SRE_Match object; span=(30, 42), match='[demolition]'>
# <_sre.SRE_Match object; span=(0, 5), match='[uai]'>
# <_sre.SRE_Match object; span=(0, 6), match='[cfab]'>
# <_sre.SRE_Match object; span=(4, 12), match='[nozzle]'>
# <_sre.SRE_Match object; span=(2, 6), match='[11]'>
# <_sre.SRE_Match object; span=(0, 10), match='[messiahs]'>
# <_sre.SRE_Match object; span=(0, 5), match='[adv]'>
# <_sre.SRE_Match object; span=(38, 48), match='[lutetium]'>
# <_sre.SRE_Match object; span=(4, 14), match='[brothers]'>
# <_sre.SRE_Match object; span=(16, 21), match='[2-8]'>
# <_sre.SRE_Match object; span=(0, 8), match='[pledge]'>
# <_sre.SRE_Match object; span=(4, 12), match='[delays]'>
# <_sre.SRE_Match object; span=(0, 6), match='[cfab]'>
# <_sre.SRE_Match object; span=(2, 6), match='[20]'>
# <_sre.SRE_Match object; span=(0, 5), match='[den]'>
# <_sre.SRE_Match object; span=(3, 8), match='[uai]'>
# <_sre.SRE_Match object; span=(0, 7), match='[mpiro]'>
# <_sre.SRE_Match object; span=(0, 6), match='[vvnt]'>
# <_sre.SRE_Match object; span=(0, 5), match='[adv]'>
# <_sre.SRE_Match object; span=(2, 6), match='[15]'>
# <_sre.SRE_Match object; span=(4, 11), match='[bacon]'>
# <_sre.SRE_Match object; span=(0, 8), match='[hubris]'>
# <_sre.SRE_Match object; span=(0, 6), match='[cfab]'>
# <_sre.SRE_Match object; span=(11, 22), match='[mortgages]'>
# <_sre.SRE_Match object; span=(4, 16), match='[mortifying]'>
# <_sre.SRE_Match object; span=(0, 11), match='[concisely]'>
# <_sre.SRE_Match object; span=(0, 4), match='[20]'>
# <_sre.SRE_Match object; span=(3, 7), match='[22]'>
# <_sre.SRE_Match object; span=(32, 39), match='[loans]'>
# <_sre.SRE_Match object; span=(25, 37), match='[5463677805]'>
# <_sre.SRE_Match object; span=(87, 94), match='[f94eq]'>
# <_sre.SRE_Match object; span=(10, 15), match='[012]'>
# <_sre.SRE_Match object; span=(23, 28), match='[PC4]'>
# <_sre.SRE_Match object; span=(41, 49), match='[salina]'>
# <_sre.SRE_Match object; span=(3, 8), match='[821]'>
# <_sre.SRE_Match object; span=(86, 93), match='[yxjdy]'>
# <_sre.SRE_Match object; span=(41, 47), match='[NVnM]'>
# <_sre.SRE_Match object; span=(0, 7), match='[Adult]'>
# <_sre.SRE_Match object; span=(3, 7), match='[20]'>
# <_sre.SRE_Match object; span=(3, 8), match='[688]'>
# <_sre.SRE_Match object; span=(67, 74), match='[us3rt]'>
# <_sre.SRE_Match object; span=(2, 6), match='[20]'>
# <_sre.SRE_Match object; span=(2, 6), match='[19]'>
# <_sre.SRE_Match object; span=(16, 33), match='[Weekly_Meg_Mail]'>
# <_sre.SRE_Match object; span=(46, 57), match='[BU-NOSPAM]'>
# <_sre.SRE_Match object; span=(82, 89), match='[tnnpr]'>
# <_sre.SRE_Match object; span=(3, 8), match='[671]'>
# <_sre.SRE_Match object; span=(87, 94), match='[b5b2l]'>
# <_sre.SRE_Match object; span=(87, 94), match='[23ca6]'>
# <_sre.SRE_Match object; span=(3, 8), match='[874]'>
# <_sre.SRE_Match object; span=(82, 89), match='[6q4pg]'>
# <_sre.SRE_Match object; span=(4, 10), match='[Daum]'>
# <_sre.SRE_Match object; span=(92, 99), match='[sj5ke]'>
# <_sre.SRE_Match object; span=(92, 99), match='[y2ao5]'>
# <_sre.SRE_Match object; span=(38, 45), match='[craft]'>
# <_sre.SRE_Match object; span=(3, 8), match='[415]'>
# <_sre.SRE_Match object; span=(16, 33), match='[Weekly_Meg_Mail]'>
# <_sre.SRE_Match object; span=(96, 104), match='[10l4ag]'>
# <_sre.SRE_Match object; span=(46, 52), match='[alma]'>
# <_sre.SRE_Match object; span=(2, 6), match='[14]'>
# <_sre.SRE_Match object; span=(60, 67), match='[vsd6D]'>
# <_sre.SRE_Match object; span=(0, 5), match='[Pub]'>
# <_sre.SRE_Match object; span=(39, 47), match='[system]'>
# <_sre.SRE_Match object; span=(96, 104), match='[gn106m]'>
# <_sre.SRE_Match object; span=(18, 29), match='[refinance]'>
# <_sre.SRE_Match object; span=(10, 17), match='[utter]'>
# <_sre.SRE_Match object; span=(3, 7), match='[30]'>
# <_sre.SRE_Match object; span=(21, 29), match='[Update]'>
# <_sre.SRE_Match object; span=(3, 7), match='[86]'>
# <_sre.SRE_Match object; span=(17, 25), match='[606047]'>
# <_sre.SRE_Match object; span=(2, 6), match='[18]'>
# <_sre.SRE_Match object; span=(16, 26), match='[aggrieve]'>
# <_sre.SRE_Match object; span=(30, 38), match='[infant]'>
# <_sre.SRE_Match object; span=(85, 92), match='[omzl2]'>
# <_sre.SRE_Match object; span=(3, 7), match='[46]'>
# <_sre.SRE_Match object; span=(67, 74), match='[dn47q]'>
# <_sre.SRE_Match object; span=(72, 79), match='[m6apa]'>
# <_sre.SRE_Match object; span=(30, 42), match='[boisterous]'>
# <_sre.SRE_Match object; span=(10, 15), match='[122]'>
# <_sre.SRE_Match object; span=(3, 7), match='[06]'>
# <_sre.SRE_Match object; span=(10, 16), match='[such]'>
# <_sre.SRE_Match object; span=(30, 36), match='[dFq5]'>

# %%
import collections
c = collections.Counter()
for entry in df['email']:
    for h in entry.keys():
        c[h] += 1

# %%
c.most_common(700)
# Out:
# [('Received', 149186),
#  ('From', 42983),
#  ('Subject', 42476),
#  ('To', 41905),
#  ('Date', 40576),
#  ('Content-Type', 38497),
#  ('Message-ID', 36445),
#  ('MIME-Version', 32644),
#  ('from', 28977),
#  ('content-type', 28903),
#  ('date', 28892),
#  ('subject', 28847),
#  ('mime-version', 28405),
#  ('to', 28220),
#  ('content-transfer-encoding', 24331),
#  ('Return-Path', 24183),
#  ('Content-Transfer-Encoding', 23298),
#  ('message-id', 16978),
#  ('X-MimeOLE', 16468),
#  ('Thread-Index', 14495),
#  ('X-MS-Has-Attach', 14166),
#  ('X-MS-TNEF-Correlator', 14008),
#  ('x-from', 13724),
#  ('x-origin', 13720),
#  ('x-to', 13720),
#  ('x-bcc', 13720),
#  ('x-filename', 13720),
#  ('x-cc', 13720),
#  ('content-class', 13266),
#  ('X-Mailer', 13228),
#  ('Thread-Topic', 13150),
#  ('x-mimeole', 12189),
#  ('x-priority', 11908),
#  ('x-msmail-priority', 11123),
#  ('Reply-To', 10338),
#  ('X-Priority', 9163),
#  ('Recieved', 8671),
#  ('received', 8454),
#  ('cc', 6720),
#  ('X-MSMail-Priority', 6346),
#  ('bcc', 6124),
#  ('Message-Id', 6067),
#  ('Cc', 5993),
#  ('Mime-Version', 4786),
#  ('x-mailer', 2595),
#  ('reply-to', 2537),
#  ('Importance', 1982),
#  ('Sender', 1657),
#  ('Content-Class', 1584),
#  ('X-Mimeole', 1510),
#  ('CC', 1441),
#  ('Content-type', 1092),
#  ('user-agent', 1009),
#  ('Priority', 935),
#  ('In-Reply-To', 928),
#  ('X-Sender', 921),
#  ('References', 911),
#  ('User-Agent', 837),
#  ('X-AntiAbuse', 825),
#  ('X-Originating-IP', 800),
#  ('Content-Disposition', 677),
#  ('MIME-version', 611),
#  ('X-Accept-Language', 541),
#  ('Precedence', 488),
#  ('x-unsent', 468),
#  ('importance', 441),
#  ('X-Message-Info', 409),
#  ('List-Unsubscribe', 387),
#  ('X-Unsent', 371),
#  ('Return-Receipt-To', 336),
#  ('Bcc', 335),
#  ('Organization', 330),
#  ('X-MIMETrack', 324),
#  ('X-Authentication-Warning', 307),
#  ('Errors-To', 299),
#  ('Location', 289),
#  ('Delivered-To', 286),
#  ('Content-transfer-encoding', 238),
#  ('Message-id', 237),
#  ('x-antiabuse', 235),
#  ('X-WSS-ID', 233),
#  ('X-Server-Uuid', 233),
#  ('Mailing-List', 231),
#  ('X-eGroups-Return', 227),
#  ('X-Apparently-To', 226),
#  ('X-mailer', 212),
#  ('sender', 186),
#  ('Reply-to', 185),
#  ('X-Originating-Email', 175),
#  ('X-Commissioner-league', 174),
#  ('Sensitivity', 174),
#  ('X-Commissioner-id', 174),
#  ('X-MIMEOLE', 172),
#  ('X-AntiVirus', 167),
#  ('X-Virus-Scanned', 167),
#  ('X-Source', 165),
#  ('X-Source-Dir', 165),
#  ('X-Source-Args', 165),
#  ('X-Yahoo-Profile', 138),
#  ('X-Roving-ID', 127),
#  ('X-Return-Path-Hint', 127),
#  ('X-Roving-Queued', 127),
#  ('Approved-By', 124),
#  ('X-Library', 122),
#  ('Delivery-Notification', 119),
#  ('Original-recipient', 114),
#  ('organization', 111),
#  ('X-VirusChecked', 110),
#  ('List-Subscribe', 107),
#  ('X-MSMail-priority', 106),
#  ('List-Owner', 106),
#  ('X-Env-Sender', 104),
#  ('X-StarScan-Version', 104),
#  ('x-accept-language', 99),
#  ('X-Info', 93),
#  ('X-Lotus-FromDomain', 91),
#  ('X-Sieve', 86),
#  ('x-sender', 86),
#  ('X-IP', 83),
#  ('return-path', 82),
#  ('x-originalarrivaltime', 81),
#  ('thread-index', 80),
#  ('Comments', 79),
#  ('Disposition-Notification-To', 77),
#  ('X-cid', 77),
#  ('X-Mailer-Version', 71),
#  ('X-MDaemon-Deliver-To', 67),
#  ('X-Return-Path', 67),
#  ('List-Id', 63),
#  ('Content-Language', 62),
#  ('content-disposition', 54),
#  ('X-Mailman-Version', 54),
#  ('TO', 53),
#  ('x-esmtp', 52),
#  ('X-Quris', 51),
#  ('x-source', 48),
#  ('x-source-args', 48),
#  ('x-source-dir', 48),
#  ('X-listname', 45),
#  ('X-MDRcpt-To', 45),
#  ('X-Message-Id', 44),
#  ('auto-submitted', 44),
#  ('X-AMAZON-TRACK', 42),
#  ('Mime-version', 42),
#  ('Errors-to', 42),
#  ('Bounces-to', 42),
#  ('List-Post', 40),
#  ('SUBJECT', 39),
#  ('X-MIME-Autoconverted', 39),
#  ('X-URL', 39),
#  ('comments', 39),
#  ('X-MDRemoteIP', 38),
#  ('List-Help', 38),
#  ('X-Zinester-PID', 37),
#  ('X-MailList-Message-ID', 37),
#  ('X-Header-Userid', 36),
#  ('X-Header-Pitchid', 36),
#  ('X-Header-Partid', 36),
#  ('X-Header-Version', 36),
#  ('X-Header-Date', 36),
#  ('Return-path', 36),
#  ('X-Original-To', 35),
#  ('X-Cq_Job', 35),
#  ('Originator', 34),
#  ('X-List-Host', 34),
#  ('X-UnityUser', 34),
#  ('X-Virus-Status', 33),
#  ('x-message-info', 33),
#  ('language', 32),
#  ('X-RAV-Antivirus', 32),
#  ('x-originating-ip', 32),
#  ('In-reply-to', 32),
#  ('status', 31),
#  ('X-EM-Registration', 30),
#  ('X-EM-Version', 30),
#  ('X-OpenMail-Hops', 30),
#  ('X-MailScanner-Information', 28),
#  ('X-MailScanner', 28),
#  ('FROM', 27),
#  ('X-RAV-AntiVirus', 27),
#  ('in-reply-to', 27),
#  ('X-Recipient_Key', 27),
#  ('X-Antivirus-Status', 26),
#  ('X-Antivirus', 26),
#  ('X-Header-Type', 26),
#  ('Originating-Server', 26),
#  ('Delivery-Class', 25),
#  ('Encoding', 25),
#  ('X-Kaspersky-Antivirus', 25),
#  ('X-MS-Attachment', 24),
#  ('X-LYRIS-Message-Id', 23),
#  ('X-Listprocessor-Version', 22),
#  ('X-Message-flag', 22),
#  ('x-failed-recipients', 22),
#  ('X-Adversend-Recipient', 21),
#  ('alternate-recipient', 21),
#  ('X-ESD', 21),
#  ('X-Adversend-MsgID', 21),
#  ('X-Adversend-Userid', 21),
#  ('x-originating-email', 21),
#  ('X-Adversend-ID', 21),
#  ('X-Sent', 20),
#  ('X-RMD-Text', 20),
#  ('X-IPAddress', 20),
#  ('X-Owner', 20),
#  ('Status', 20),
#  ('X-db', 19),
#  ('Content-Description', 19),
#  ('Envelope-Sender', 19),
#  ('X-Organization', 18),
#  ('domainkey-signature', 18),
#  ('X-GMX-Antivirus', 18),
#  ('x_uid', 18),
#  ('x-satatus', 18),
#  ('x-keywords', 18),
#  ('Content-Location', 17),
#  ('X-UnityID', 17),
#  ('X-Original-Date', 17),
#  ('Content-Return', 17),
#  ('X-Batch-Number', 17),
#  ('X400-Received', 16),
#  ('x-library', 16),
#  ('X-LISTMANAGERSQL-Message-Id', 16),
#  ('priority', 16),
#  ('X-MID', 16),
#  ('X-Message-id', 16),
#  ('X-LSMTP-Document-ID', 15),
#  ('X-DJ-TopicName', 15),
#  ('X-BFI', 15),
#  ('X-DJ-IntendedRecipient', 15),
#  ('X-MsgID', 14),
#  ('X-ECS-MailScanner', 14),
#  ('X-ListID', 14),
#  ('precedence', 14),
#  ('X-SubID', 14),
#  ('Content-return', 14),
#  ('X-EntryID', 14),
#  ('X-Yahoo-Bounces', 14),
#  ('X-PMG-Msgid', 13),
#  ('X-PMG-Recipient', 13),
#  ('X-Message-Flag', 13),
#  ('X-PMG-Userid', 13),
#  ('X-Spam-Status', 13),
#  ('X-Yahoo-MMID', 13),
#  ('X-Complain-To', 13),
#  ('thread-topic', 13),
#  ('X-Yahoo-MMO', 13),
#  ('X-CS-IP', 13),
#  ('errors-to', 13),
#  ('x-ms-tnef-correlator', 12),
#  ('x-mozilla-status', 12),
#  ('List-ID', 12),
#  ('x-mozilla-status2', 12),
#  ('x-ms-has-attach', 12),
#  ('X-Scanned-By', 11),
#  ('fcc', 11),
#  ('HOP-COUNT', 11),
#  ('X-MDMailing-List', 11),
#  ('original-recipient', 11),
#  ('X-EXP32-SerialNo', 11),
#  ('x-identity-key', 11),
#  ('X-WebMail-UserID', 11),
#  ('X-MDSend-Notifications-To', 11),
#  ('x-ip', 11),
#  ('Alternate-Recipient', 11),
#  ('X-Identity-Key', 11),
#  ('disclose-recipients', 11),
#  ('X-MAILWATCH-INSTANCEID', 11),
#  ('x-dsncontext', 11),
#  ('FCC', 11),
#  ('X_UID', 10),
#  ('X-Satatus', 10),
#  ('approved', 10),
#  ('MailFrom', 10),
#  ('X-WDR-Disclaimer', 10),
#  ('X-Keywords', 10),
#  ('references', 10),
#  ('X-AOL-IP', 10),
#  ('Delivery-date', 10),
#  ('X-Spam-Level', 10),
#  ('x-spam-status', 10),
#  ('x-antivirus', 10),
#  ('X-Topica-Id', 10),
#  ('DATE', 10),
#  ('x-account-key', 10),
#  ('Conversion', 9),
#  ('x-virus-scanned', 9),
#  ('x-antivirus-status', 9),
#  ('X-Mail-Agent', 9),
#  ('X-Webmailer-Time', 9),
#  ('X-RBL-Warning', 9),
#  ('x-webmail-time', 9),
#  ('X-igwMailID', 9),
#  ('x-uidl', 9),
#  ('disposition-notification-to', 9),
#  ('Content-disposition', 9),
#  ('X-MailScanner-From', 9),
#  ('X400-MTS-Identifier', 8),
#  ('X-EMA-CID', 8),
#  ('X400-Originator', 8),
#  ('X-DeliverBy', 8),
#  ('x-spam-level', 8),
#  ('X-Mozilla-Status2', 8),
#  ('X400-Content-Type', 8),
#  ('X-EmailedTo', 8),
#  ('X-Mozilla-Status', 8),
#  ('Original-Encoded-Information-Types', 8),
#  ('X-QM-SEND-ID', 8),
#  ('X-No-Archive', 8),
#  ('X-Archived', 8),
#  ('X-UserId', 8),
#  ('Disclose-Recipients', 8),
#  ('X400-Recipients', 8),
#  ('Original-Recipient', 8),
#  ('Content-Identifier', 8),
#  ('X-EMA-PC', 8),
#  ('X-Spam-Checker-Version', 8),
#  ('X-JobId', 8),
#  ('X-EMA-LID', 8),
#  ('x-apparently-to', 7),
#  ('X-VMS-To', 7),
#  ('content-language', 7),
#  ('Content-language', 7),
#  ('conversion', 7),
#  ('X-Interface', 7),
#  ('sensitivity', 7),
#  ('X-AOL-Language', 7),
#  ('comment', 7),
#  ('X-Loop', 7),
#  ('list-unsubscribe', 7),
#  ('X-AM-MSGID', 7),
#  ('X-Webmail-Time', 7),
#  ('x-mime-autoconverted', 7),
#  ('X-Spam-Processed', 7),
#  ('Thread-index', 7),
#  ('X-BeenThere', 7),
#  ('list-id', 7),
#  ('X-eGroups-Announce', 7),
#  ('delivered-to', 7),
#  ('X-Bulkmail', 6),
#  ('X-ClientAddr', 6),
#  ('X-Encoding', 6),
#  ('Reply-By', 6),
#  ('X-Expid', 6),
#  ('X-SA-Exim-Mail-From', 6),
#  ('X_Id', 6),
#  ('Delivery-Date', 6),
#  ('x-receiver', 6),
#  ('resent-reply-to', 6),
#  ('received-spf', 6),
#  ('BCc', 6),
#  ('X-Hashcash', 6),
#  ('X-MAILER', 6),
#  ('X-Juno-Line-Breaks', 6),
#  ('X-JMSavedFile', 6),
#  ('x-spam-checker-version', 6),
#  ('return-receipt-to', 6),
#  ('X-Types', 6),
#  ('X-SureCom-User', 6),
#  ('x-scanned', 5),
#  ('X-ATID', 5),
#  ('X-PID', 5),
#  ('X-Sensitivity', 5),
#  ('X-Note', 5),
#  ('x-sa-exim-mail-from', 5),
#  ('X-SMTPExp-Version', 5),
#  ('X-AIMC-AUTH', 5),
#  ('X-IMAIL-SPAM-VALHELO', 5),
#  ('X-DSNContext', 5),
#  ('X-Intended-Recipient', 5),
#  ('X-XaM3-API-Version', 5),
#  ('X-type', 5),
#  ('X-eGroups-Application', 5),
#  ('X-SMRID', 5),
#  ('x-batch-number', 5),
#  ('X-SenderIP', 5),
#  ('X-Provags-ID', 5),
#  ('X-SA-Exim-Scanned', 5),
#  ('X-Apparently-From', 5),
#  ('X-SMTPExp-Registration', 5),
#  ('X-SA-Exim-Version', 5),
#  ('X-SA-Exim-Connect-IP', 5),
#  ('X-Original-Return-Path', 5),
#  ('x-sa-exim-connect-ip', 5),
#  ('X-AIMC-MAILFROM', 5),
#  ('X-MS-Embedded-Report', 5),
#  ('x-confirm-reading-to', 4),
#  ('X-Comments', 4),
#  ('X-DNS-problems', 4),
#  ('X-Server', 4),
#  ('X-Sender-Ip', 4),
#  ('X-Streetmail-Checksum', 4),
#  ('X-Abuse-complaints', 4),
#  ('X-Sent-Mail', 4),
#  ('x-email', 4),
#  ('x-loop', 4),
#  ('X-Version', 4),
#  ('MiME-Version', 4),
#  ('X-Msmail-Priority', 4),
#  ('X-Spam-Score', 4),
#  ('Authentication-Results', 4),
#  ('mailing-list', 4),
#  ('X-Mailbox-Line', 4),
#  ('X-Account-Key', 4),
#  ('X-Declude-Sender', 4),
#  ('x-mdaemon-deliver-to', 4),
#  ('X-Email-problems', 4),
#  ('Notification', 4),
#  ('X-IXS-Message-Id', 4),
#  ('content-alias', 4),
#  ('x-cid', 4),
#  ('x-yahoo-newman-property', 4),
#  ('X-parse', 4),
#  ('x-userid', 4),
#  ('returnpath', 4),
#  ('X-Mozilla-Draft-Info', 4),
#  ('X-Originator', 4),
#  ('Auto-Submitted', 4),
#  ('x-return-path', 4),
#  ('x-mid', 4),
#  ('x-mdsend-notifications-to', 3),
#  ('Apparently-To', 3),
#  ('x-kernel', 3),
#  ('x-mdav-processed', 3),
#  ('x-yahoo-profile', 3),
#  ('x-authenticated-sender', 3),
#  ('x-mdremoteip', 3),
#  ('X-eGroups-From', 3),
#  ('x-qm-template', 3),
#  ('X-IMAIL-SPAM-STATISTICS', 3),
#  ('x-egroups-approved-by', 3),
#  ('X-Originating-Ip', 3),
#  ('X-Spam-Report', 3),
#  ('Expiry-Date', 3),
#  ('X-MDAV-Processed', 3),
#  ('Content-class', 3),
#  ('X-Spam-Warning', 3),
#  ('X-SID-PRA', 3),
#  ('X-Message-Status', 3),
#  ('list-help', 3),
#  ('X-Envelope-Sender-Is', 3),
#  ('x-spam-processed', 3),
#  ('List-Software', 3),
#  ('x-egroups-msg-info', 3),
#  ('X-Spam-Flag', 3),
#  ('X-ECRMMemberIdTag', 3),
#  ('x-unsubscribe', 3),
#  ('X-OriginatingIP', 3),
#  ('X-ECRMClientTypeTag', 3),
#  ('X-Authenticated-User', 3),
#  ('Content-description', 3),
#  ('X-VirtualServer', 3),
#  ('Received-Date', 3),
#  ('X-LISTMANAGER-Message-Id', 3),
#  ('discarded-x400-mts-extensions', 3),
#  ('Language', 3),
#  ('Originator-Info', 3),
#  ('X-Original-IP', 3),
#  ('X-mailer-Time', 3),
#  ('x-autorespond', 3),
#  ('X-ECRMMessageIdTag', 3),
#  ('x-mdmailing-list', 3),
#  ('X-SID-Result', 3),
#  ('X-AOL-Test', 3),
#  ('disposition-notification-options', 2),
#  ('x-mailmerge', 2),
#  ('X-UTIC-MailScanner', 2),
#  ('X-imss-version', 2),
#  ('list-post', 2),
#  ('0X-Accept-Language', 2),
#  ('X-PAA-AntiVirus-Message', 2),
#  ('X-Spam-Tests-Failed', 2),
#  ('X-pmrqc', 2),
#  ('X-Declude-Scan', 2),
#  ('Thread-topic', 2),
#  ('submit-conf', 2),
#  ('x-habeas-swe-5', 2),
#  ('X-UTIC-MailScanner-Information', 2),
#  ('X-Amazon-ORDER-Recipient', 2),
#  ('X-Powered-By', 2),
#  ('x-msgid', 2),
#  ('x-fs-spamassassinscore', 2),
#  ('x-pmrqc', 2),
#  ('X-Amazon-ORDER-Sender', 2),
#  ('x-campaign', 2),
#  ('x-mailtype', 2),
#  ('x-fs-spamassassinrules', 2),
#  ('X-Origin', 2),
#  ('X-OEM', 2),
#  ('X-WebsiteUser-IP', 2),
#  ('X-Complaints-To', 2),
#  ('X-Scan-Signature', 2),
#  ('X-BouncyBouncyID', 2),
#  ('X-Orcpt', 2),
#  ('X-Server-Id', 2),
#  ('X-NAS-MessageID', 2),
#  ('X-imss-scores', 2),
#  ('original-encoded-information-types', 2),
#  ('X-FREE-OF-KNOWN-WORMS', 2),
#  ('X-Declude-Note', 2),
#  ('x-sa-exim-scanned', 2),
#  ('Content-MD5', 2),
#  ('X-User-Agent', 2),
#  ('x-habeas-swe-4', 2),
#  ('x-gmail-received', 2),
#  ('x-habeas-swe-3', 2),
#  ('x-habeas-swe-9', 2),
#  ('x-habeas-swe-8', 2),
#  ('X-message-flag', 2),
#  ('Reference', 2),
#  ('x-user_ip', 2),
#  ('X-NAS-Validation', 2),
#  ('X-IMAIL-SPAM-DNSBL', 2),
#  ('X-imss-result', 2),
#  ('x-authenticated-user', 2),
#  ('x-habeas-swe-7', 2),
#  ('X-Msg-Ref', 2),
#  ('X-Country-Chain', 2),
#  ('X-Hosted-By', 2),
#  ('Target-Charset', 2),
#  ('X-USER_IP', 2),
#  ('X-Envelope-To', 2),
#  ('X-Memo', 2),
#  ('X-From-OFFICEVISION', 2),
#  ('X-ORSAppealID', 2),
#  ('prevent-nondelivery-report', 2),
#  ('X-Http_host', 2),
#  ('X-Filtered-By', 2),
#  ('X-Declude-Fail', 2),
#  ('x-icpinfo', 2),
#  ('X-AG-MIPS', 2),
#  ('x-habeas-swe-1', 2),
#  ('x-fid', 2),
#  ('x-habeas-swe-2', 2),
#  ('MMDF-Warning', 2),
#  ('x-mimetrack', 2),
#  ('X-Webmail-User', 2),
#  ('x-habeas-swe-6', 2),
#  ('X-Useless-Harpo-header', 2),
#  ('X-imss-settings', 2),
#  ('x-authentication-warning', 2),
#  ('X-eGroups-Approved-By', 2),
#  ('X-Confirm-Reading-To', 2),
#  ('X-DCX', 2),
#  ('x-return-path-hint', 2),
#  ('X-Amazon-ORDER-Date', 2),
#  ('X-NAI-Modified', 2),
#  ('X-PAA-AntiVirus', 2),
#  ('X-NAS-Classification', 2),
#  ('X-Declude-Spoolname', 2),
#  ('Resent-Reply-To', 2),
#  ('x-mailcategory', 2),
#  ('msg-id', 2),
#  ('X-UIDL', 2),
#  ('X-Amazon-ORDER-Sender-IP', 2),
#  ('accreditor', 2),
#  ('X-cnnid', 2),
#  ('x-scanner', 2),
#  ('submit-chsm', 2),
#  ('x-cbomsgid', 2),
#  ('Content-ID', 2),
#  ('X-Daibert-MailScanner-From', 1),
#  ('x-identify', 1),
#  ('bounces-to', 1),
#  ('envelope-to', 1),
#  ('X-Yahoo-nmail', 1),
#  ('X-ScriptPath', 1),
#  ('X-thetnet-MailScanner-Information', 1),
#  ('x-em-version', 1),
#  ('X-LOCAL', 1),
#  ('X-ReceivedInfo', 1),
#  ('X-cPanel-MailScanner-From', 1),
#  ('X-BitDefender-Scanner', 1),
#  ('X-Operating-System', 1),
#  ('x-brightmailfiltered', 1),
#  ('resent-date', 1),
#  ('MIME_Version', 1),
#  ('X-SLUIDL', 1),
#  ('XMailing-Id', 1),
#  ('X-TTN-MailScanner', 1),
#  ('X-yahoo-newman-property', 1),
#  ('X-Vwebmail-Auth', 1),
#  ('X-mid', 1),
#  ('x-dsnid', 1),
#  ('X-RCPT-TO', 1),
#  ('X-Firefly-MailScanner-SpamCheck', 1),
#  ('0MIME-Version', 1),
#  ('X-EA-Trace', 1),
#  ('FILETIME=[yGfMRTWhnbjNcK', 1),
#  ('x-eds-source-name', 1),
#  ('list-archive', 1),
#  ('X-pmuue', 1),
#  ('Auto-Forwarded', 1),
#  ('X-Amazon-Card-Sender-IP', 1),
#  ('X-Bogosity', 1),
#  ('X-Checksum', 1),
#  ('X-pid', 1),
#  ('X-WebMail-Company', 1),
#  ('X-Processed-By', 1),
#  ('X-eSCM-MailFrom', 1),
#  ('X-TTN-MailScanner-SpamCheck', 1),
#  ('X-List-Software', 1),
#  ('x-original-date', 1),
#  ('X-cPanel-MailScanner', 1),
#  ('X-yahoo-newman-expires', 1),
#  ('x-anti-virus', 1),
#  ('X-NAI-Spam-Rules', 1),
#  ('resent-from', 1),
#  ('Reply-by', 1),
#  ('x-mailer-version', 1),
#  ('list-subscribe', 1),
#  ('X-Daibert-MailScanner-To', 1),
#  ('X-MessageID', 1),
#  ('X-Junkmail-Status', 1),
#  ('content-Transfer-Encoding', 1),
#  ('X-Via', 1),
#  ('x-sending-host', 1),
#  ('x-original-ip', 1),
#  ('x-tnz-problem-type', 1),
#  ('X-MailSessionID', 1),
#  ('X-Spam', 1),
#  ('auth-sender', 1),
#  ('x-server', 1),
#  ('X-finfo', 1),
#  ('Relpy-To', 1),
#  ('x-orbl', 1),
#  ('X-Sent-From', 1),
#  ('X-WebTV-Signature', 1),
#  ('xType', 1),
#  ('X-HR-ClamAV-Scan', 1),
#  ('X-Loop-Detect', 1),
#  ('X-INFO_BZ', 1),
#  ('X-HTTP-HOST', 1),
#  ('mimeole', 1),
#  ('X-Thaisite.net-MailScanner', 1),
#  ('-Message-Info', 1),
#  ('x-scanned-by', 1),
#  ('X-Loop-Check', 1),
#  ('ReceivedDate', 1),
#  ('x-eds-source-ip', 1),
#  ('X-Fib-Al', 1),
#  ('X-WEBC-Mail-From-Script', 1),
#  ('x-cs-ip', 1),
#  ('x-tmorder', 1),
#  ('X-Brightmail-Tracker', 1),
#  ('X-AGSite', 1),
#  ('Resent-date', 1),
#  ('Resent-Message-Id', 1),
#  ('Body', 1),
#  ('x-mailscanner-spamscore', 1),
#  ('X-Provider', 1),
#  ('x-id', 1),
#  ('x-en-authuser', 1),
#  ('FILETIME=[RKSpjEzLp', 1),
#  ('eceived', 1),
#  ('X_Mailer', 1),
#  ('X-NS13-MailScanner-SpamCheck', 1),
#  ('X-Spam-Detected', 1),
#  ('X-NAI-Spam-Score', 1),
#  ('X-Amazon-Card-PickupID', 1),
#  ('X-Amazon-Card-OUID', 1),
#  ('X-Thaisite.net-MailScanner-Information', 1),
#  ('X-hostpartner-MailScanner', 1),
#  ('x-mb-message-source', 1),
#  ('X-SMTP-PEER-INFO', 1),
#  ('Content-Base', 1),
#  ('x-en-userinfo', 1),
#  ('X-HR-SA-Score', 1),
#  ('X-ME-UUID', 1),
#  ('X-Authenticated-Sender', 1),
#  ('content-Type', 1),
#  ('CONTENT-TYPE', 1),
#  ('X-Iden-Server', 1),
#  ('x-mailscanner', 1),
#  ('X-thetnet-MailScanner-SpamCheck', 1),
#  ('Xref', 1),
#  ('X-Brand', 1),
#  ('X-ClientID', 1),
#  ('X-e-places-MailScanner-Information', 1),
#  ('x-skrzynka-av', 1),
#  ('X-MMLanguage', 1),
#  ('AG-BBI', 1),
#  ('X-Pathfinder.gr-MailScanner-Information', 1),
#  ('x-no-archive', 1),
#  ('x-aol-ip', 1),
#  ('old-return-path', 1),
#  ('X-HR-Status', 1),
#  ('X-z2c-Tracer', 1),
#  ('x-spam-score', 1),
#  ('X-cPanel-MailScanner-SpamCheck', 1),
#  ('X-thetnet-MailScanner-SpamScore', 1),
#  ('X-TTN-MailScanner-Information', 1),
#  ('X-Uidl', 1),
#  ('X-INFO_CZ', 1),
#  ('X-Seg', 1),
#  ('Suvladi.Pimenovject', 1),
#  ('X-Junkmail', 1),
#  ('X-Amazon-Date', 1),
#  ('X-SMTP-HELO', 1),
#  ('MAILER-TRACE', 1)]

# %%
for k in c:
    if re.match(r'.*list.*', k) is not None:
        print(k)
# Out:
# list-post
# list-archive
# list-subscribe
# mailing-list
# X-listname
# list-unsubscribe
# list-help
# x-list-administrivia
# list-id
# x-mdmailing-list
# x-mailing-list
# x-mailer-listid

# %%
df['email'].apply(lambda x: '#' in x['from'] if x['from'] is not None else False).describe()
# Out:
# count     72027
# unique        2
# top       False
# freq      43162
# Name: email, dtype: object
